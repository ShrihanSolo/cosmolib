# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from twopoint import twopoint
import plot
from numpy.lib import recfunctions as rfn
import os

# %%
weaklens_dir = Path.cwd().parent.parent
run_dir = weaklens_dir / "clean_sims" / "LSSTY1" / "dcrimprint2pt" / "A"

# %%
# Load in the data

import pickle

npairs_dict = {}

for i in range(0, 5):
    for j in range(0, i + 1):
        pickle_file = run_dir / "results/gg_r{0}{1}.pickle".format(j, i)
        print(pickle_file)
        with open(pickle_file, 'rb') as f:
            gg_data = pickle.load(f)
            npairs_dict[(j + 1, i + 1)] = gg_data.npairs

cross_xip = {}
cross_xim = {}
theta_corr = {}

# Load the xip and jackknife uncertainty in xip from treecorr for each binning
for i in range(0, 5):
    for j in range(0, i + 1):
        cross_xip[(j + 1, i + 1)] = np.load(run_dir / "results/xip_corr_r{0}{1}.npy".format(j, i))
        cross_xim[(j + 1, i + 1)] = np.load(run_dir / "results/xim_corr_r{0}{1}.npy".format(j, i))
        theta_corr[(j + 1, i + 1)] = np.load(run_dir / "results/theta_corr_r{0}{1}.npy".format(j, i))
# Out:
# /home/shrihan/weaklens/clean_sims/LSSTY1/dcrimprint2pt/A/results/gg_r00.pickle
# /home/shrihan/weaklens/clean_sims/LSSTY1/dcrimprint2pt/A/results/gg_r01.pickle
# /home/shrihan/weaklens/clean_sims/LSSTY1/dcrimprint2pt/A/results/gg_r11.pickle
# /home/shrihan/weaklens/clean_sims/LSSTY1/dcrimprint2pt/A/results/gg_r02.pickle
# /home/shrihan/weaklens/clean_sims/LSSTY1/dcrimprint2pt/A/results/gg_r12.pickle
# /home/shrihan/weaklens/clean_sims/LSSTY1/dcrimprint2pt/A/results/gg_r22.pickle
# /home/shrihan/weaklens/clean_sims/LSSTY1/dcrimprint2pt/A/results/gg_r03.pickle
# /home/shrihan/weaklens/clean_sims/LSSTY1/dcrimprint2pt/A/results/gg_r13.pickle
# /home/shrihan/weaklens/clean_sims/LSSTY1/dcrimprint2pt/A/results/gg_r23.pickle
# /home/shrihan/weaklens/clean_sims/LSSTY1/dcrimprint2pt/A/results/gg_r33.pickle
# /home/shrihan/weaklens/clean_sims/LSSTY1/dcrimprint2pt/A/results/gg_r04.pickle
# /home/shrihan/weaklens/clean_sims/LSSTY1/dcrimprint2pt/A/results/gg_r14.pickle
# /home/shrihan/weaklens/clean_sims/LSSTY1/dcrimprint2pt/A/results/gg_r24.pickle
# /home/shrihan/weaklens/clean_sims/LSSTY1/dcrimprint2pt/A/results/gg_r34.pickle
# /home/shrihan/weaklens/clean_sims/LSSTY1/dcrimprint2pt/A/results/gg_r44.pickle

# %%
fpath = Path("old_runs/giulia_2pt/giulia_2pt_example.fits")
ffile = fits.open(fpath)
del ffile[4:6] # remove gamma_t and wtheta
del ffile[-1] # remove nz_lens

# %%
ffile.info()
# Out:
# Filename: old_runs/giulia_2pt/giulia_2pt_example.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  COVMAT        1 ImageHDU        17   (1000, 1000)   float64
#   2  xip           1 BinTableHDU     39   200R x 8C   [K, K, K, D, D, D, D, D]
#   3  xim           1 BinTableHDU     39   200R x 8C   [K, K, K, D, D, D, D, D]
#   4  nz_source     1 BinTableHDU     32   300R x 7C   [D, D, D, D, D, D, D]

# %%
ffile[2].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   64 / length of dimension 1
# NAXIS2  =                  200 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                    8 / number of table fields
# 2PTDATA =                    T
# EXTNAME = 'xip     '
# QUANT1  = 'G+R     '
# QUANT2  = 'G+R     '
# KERNEL_1= 'nz_source'
# KERNEL_2= 'nz_source'
# WINDOWS = 'SAMPLE  '
# N_ZBIN_1=                    4
# N_ZBIN_2=                    4
# N_ANG   =                   20
# TTYPE1  = 'BIN1    '
# TFORM1  = 'K       '
# TTYPE2  = 'BIN2    '
# TFORM2  = 'K       '
# TTYPE3  = 'ANGBIN  '
# TFORM3  = 'K       '
# TTYPE4  = 'VALUE   '
# TFORM4  = 'D       '
# TTYPE5  = 'ANGLEMIN'
# TFORM5  = 'D       '
# TUNIT5  = 'arcmin  '
# TTYPE6  = 'ANGLEMAX'
# TFORM6  = 'D       '
# TUNIT6  = 'arcmin  '
# TTYPE7  = 'ANG     '
# TFORM7  = 'D       '
# TUNIT7  = 'arcmin  '
# TTYPE8  = 'NPAIRS  '
# TFORM8  = 'D       '
# BLINDED = 'add     '
# KEYWORD = 'mdet_bruschetta_al_pomodoro'

# %%
ffile[2].data
# Out:
# FITS_rec([(1, 1,  0, 3.39719726e-05,   2.5       ,   3.14731353,   2.8290551 , 4.47010214e+08),
# %%
xip_data = ffile[2].data
xim_data = ffile[3].data

# Build extended arrays with 300 rows
n_old = len(xip_data)       # 200
n_new = 15 * 20             # 300

def extend_data(old_data, n_new):
    new_data = np.recarray(n_new, dtype=old_data.dtype)
    # Copy old rows
    for name in old_data.dtype.names:
        new_data[name][:len(old_data)] = old_data[name]
    return new_data

xip_data_new = extend_data(xip_data, n_new)
xim_data_new = extend_data(xim_data, n_new)

# Fill in BIN1, BIN2, ANGBIN, ANGLEMIN, ANGLEMAX, ANG for the new 100 rows
for j in range(5 * 20):
    i = n_old + j 
    bin_num = j // 20 + 1
    ang_bin = xip_data['ANGBIN'][j]
    angle_min = xip_data['ANGLEMIN'][j]
    angle_max = xip_data['ANGLEMAX'][j]
    ang = xip_data['ANG'][j]
    xip_data_new['BIN1'][i] = bin_num
    xip_data_new['BIN2'][i] = 5
    xip_data_new['ANGBIN'][i] = ang_bin
    xip_data_new['ANGLEMIN'][i] = angle_min
    xip_data_new['ANGLEMAX'][i] = angle_max
    xip_data_new['ANG'][i] = ang
    xim_data_new['BIN1'][i] = bin_num
    xim_data_new['BIN2'][i] = 5
    xim_data_new['ANGBIN'][i] = ang_bin
    xim_data_new['ANGLEMIN'][i] = angle_min
    xim_data_new['ANGLEMAX'][i] = angle_max
    xim_data_new['ANG'][i] = ang

val_xip = np.zeros(15 * 20)
val_xim = np.zeros(15 * 20)
npairs = np.zeros(15 * 20)

for i in range(len(val_xip)):
    val_xip[i] = cross_xip[(xip_data_new['BIN1'][i], xip_data_new['BIN2'][i])][xip_data_new['ANGBIN'][i]]
    val_xim[i] = cross_xim[(xim_data_new['BIN1'][i], xim_data_new['BIN2'][i])][xim_data_new['ANGBIN'][i]]
    npairs[i] = npairs_dict[(xip_data_new['BIN1'][i], xip_data_new['BIN2'][i])][xip_data_new['ANGBIN'][i]]

xip_data_new['VALUE'] = val_xip
xim_data_new['VALUE'] = val_xim
xip_data_new['NPAIRS'] = npairs
xim_data_new['NPAIRS'] = npairs

# ffile[2].data = xip_data_new
# ffile[3].data = xim_data_new

def rebuild_hdu(original_hdu, new_data):
    # Build new columns from the new data, preserving format and unit from original
    original_cols = original_hdu.columns
    col_dict = {col.name: col for col in original_cols}
    
    new_cols = []
    for name in new_data.dtype.names:
        orig = col_dict[name]
        new_cols.append(fits.Column(
            name=orig.name,
            format=orig.format,
            unit=orig.unit,          # <-- preserves TUNIT (e.g. 'arcmin')
            array=new_data[name]
        ))
    
    # Build new HDU and copy over the non-column header cards
    new_hdu = fits.BinTableHDU.from_columns(new_cols)
    for key, val in original_hdu.header.items():
        if key not in new_hdu.header and key not in ('NAXIS1', 'NAXIS2', 'TFIELDS'):
            try:
                new_hdu.header[key] = val
            except Exception:
                pass
    new_hdu.name = original_hdu.name
    new_hdu.header['EXTNAME'] = original_hdu.name.lower()
    return new_hdu

ffile[2] = rebuild_hdu(ffile[2], xip_data_new)
ffile[3] = rebuild_hdu(ffile[3], xim_data_new)

ffile[2].header['N_ZBIN_1'] = 5
ffile[2].header['N_ZBIN_2'] = 5
ffile[3].header['N_ZBIN_1'] = 5
ffile[3].header['N_ZBIN_2'] = 5

# %%
ffile[3].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   64 / length of dimension 1
# NAXIS2  =                  300 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                    8 / number of table fields
# TTYPE1  = 'BIN1    '
# TFORM1  = 'K       '
# TTYPE2  = 'BIN2    '
# TFORM2  = 'K       '
# TTYPE3  = 'ANGBIN  '
# TFORM3  = 'K       '
# TTYPE4  = 'VALUE   '
# TFORM4  = 'D       '
# TTYPE5  = 'ANGLEMIN'
# TFORM5  = 'D       '
# TUNIT5  = 'arcmin  '
# TTYPE6  = 'ANGLEMAX'
# TFORM6  = 'D       '
# TUNIT6  = 'arcmin  '
# TTYPE7  = 'ANG     '
# TFORM7  = 'D       '
# TUNIT7  = 'arcmin  '
# TTYPE8  = 'NPAIRS  '
# TFORM8  = 'D       '
# 2PTDATA =                    T
# EXTNAME = 'xim     '
# QUANT1  = 'G-R     '
# QUANT2  = 'G-R     '
# KERNEL_1= 'nz_source'
# KERNEL_2= 'nz_source'
# WINDOWS = 'SAMPLE  '
# N_ZBIN_1=                    5
# N_ZBIN_2=                    5
# N_ANG   =                   20
# BLINDED = 'add     '
# KEYWORD = 'mdet_bruschetta_al_pomodoro'

# %%
ffile[2].data
# Out:
# FITS_rec([(1, 1,  0, 5.97039620e-06,   2.5       ,   3.14731353,   2.8290551 , 3.28976143e+09),
#           (1, 1,  1, 5.11216884e-06,   3.14731353,   3.96223298,   3.56172569, 5.17562309e+09),
#           (1, 1,  2, 4.33067327e-06,   3.96223298,   4.98815579,   4.48403221, 8.20452874e+09),
#           (1, 1,  3, 3.62986427e-06,   4.98815579,   6.27971608,   5.64521982, 1.30049875e+10),
#           (1, 1,  4, 3.00669525e-06,   6.27971608,   7.90569415,   7.10706514, 2.06120708e+10),
#           (1, 1,  5, 2.46485465e-06,   7.90569415,   9.95267926,   8.9477756 , 3.26658548e+10),
#           (1, 1,  6, 2.00724956e-06,   9.95267926,  12.52968084,  11.26400148, 5.17638792e+10),
#           (1, 1,  7, 1.63449614e-06,  12.52968084,  15.77393361,  14.18063413, 8.20155474e+10),
#           (1, 1,  8, 1.33521805e-06,  15.77393361,  19.85820587,  17.85302577, 1.29923133e+11),
#           (1, 1,  9, 1.09783641e-06,  19.85820587,  25.        ,  22.47486282, 2.05769883e+11),
#           (1, 1, 10, 9.07749147e-07,  25.        ,  31.47313529,  28.29515278, 3.25799569e+11),
#           (1, 1, 11, 7.57380782e-07,  31.47313529,  39.62232981,  35.6203863 , 5.15670475e+11),
#           (1, 1, 12, 6.34120154e-07,  39.62232981,  49.88155787,  44.84313437, 8.15896412e+11),
#           (1, 1, 13, 5.35091039e-07,  49.88155787,  62.79716079,  56.4542325 , 1.29012497e+12),
#           (1, 1, 14, 4.47698399e-07,  62.79716079,  79.0569415 ,  71.07017994, 2.03848893e+12),
#           (1, 1, 15, 3.73996425e-07,  79.0569415 ,  99.52679264,  89.47027565, 3.21895125e+12),
#           (4, 5, 14, 5.25905838e-06,  62.79716079,  79.0569415 ,  71.070527  , 2.04090586e+12),
#           (4, 5, 15, 3.70535231e-06,  79.0569415 ,  99.52679264,  89.47001907, 3.22277184e+12),
#           (4, 5, 16, 2.49693269e-06,  99.52679264, 125.29680841, 112.63622727, 5.08225361e+12),
#           (4, 5, 17, 1.65406677e-06, 125.29680841, 157.73933612, 141.79301199, 8.00467947e+12),
#           (4, 5, 18, 1.01563655e-06, 157.73933612, 198.58205868, 178.50398779, 1.25818308e+13),
#           (4, 5, 19, 6.07792894e-07, 198.58205868, 250.        , 224.72248041, 1.97435976e+13),
#           (5, 5,  0, 1.75976609e-04,   2.5       ,   3.14731353,   2.82898181, 3.29335460e+09),
#           (5, 5,  1, 1.44275170e-04,   3.14731353,   3.96223298,   3.56161099, 5.18148044e+09),
#           (5, 5,  2, 1.19308648e-04,   3.96223298,   4.98815579,   4.48401037, 8.21376765e+09),
#           (5, 5,  3, 1.00242607e-04,   4.98815579,   6.27971608,   5.64522328, 1.30195380e+10),
#           (5, 5,  4, 8.40399740e-05,   6.27971608,   7.90569415,   7.10701611, 2.06356005e+10),
#           (5, 5,  5, 7.03250748e-05,   7.90569415,   9.95267926,   8.94784503, 3.27035023e+10),
#           (5, 5,  6, 5.87189371e-05,   9.95267926,  12.52968084,  11.26394834, 5.18228590e+10),
#           (5, 5,  7, 4.86866536e-05,  12.52968084,  15.77393361,  14.18057494, 8.21085344e+10),
#           (5, 5,  8, 3.99371169e-05,  15.77393361,  19.85820587,  17.85308976, 1.30071657e+11),
#           (5, 5,  9, 3.22232629e-05,  19.85820587,  25.        ,  22.47463144, 2.06005622e+11),
#           (5, 5, 10, 2.54133596e-05,  25.        ,  31.47313529,  28.29519749, 3.26173536e+11),
#           (5, 5, 11, 1.95059756e-05,  31.47313529,  39.62232981,  35.62005605, 5.16262956e+11),
#           (5, 5, 12, 1.47096275e-05,  39.62232981,  49.88155787,  44.84263737, 8.16833465e+11),
#           (5, 5, 13, 1.07343191e-05,  49.88155787,  62.79716079,  56.4537835 , 1.29160838e+12),
#           (5, 5, 14, 7.51151614e-06,  62.79716079,  79.0569415 ,  71.06932913, 2.04082137e+12),
#           (5, 5, 15, 5.07485294e-06,  79.0569415 ,  99.52679264,  89.46908394, 3.22262036e+12),
#           (5, 5, 16, 3.26583999e-06,  99.52679264, 125.29680841, 112.63417879, 5.08197720e+12),
#           (5, 5, 17, 2.07277469e-06, 125.29680841, 157.73933612, 141.79160977, 8.00426647e+12),
#           (5, 5, 18, 1.18574888e-06, 157.73933612, 198.58205868, 178.50189795, 1.25810147e+13),
#           (5, 5, 19, 6.17996777e-07, 198.58205868, 250.        , 224.71940732, 1.97423540e+13)],
#          dtype=(numpy.record, [('BIN1', '<i8'), ('BIN2', '<i8'), ('ANGBIN', '<i8'), ('VALUE', '<f8'), ('ANGLEMIN', '<f8'), ('ANGLEMAX', '<f8'), ('ANG', '<f8'), ('NPAIRS', '<f8')]))

# %%
# !cat ../../cosmocow/covs/output/out_cov_lssty1_shrihan/l* > covdata_lssty1.txt

# %%
cov_g, cov_ng, ndata = plot.get_cov("covdata_lssty1.txt")
cov = cov_g + cov_ng
pp_norm = np.zeros((ndata,ndata))
for i in range(ndata):
    for j in range(ndata):
        pp_norm[i][j] = cov[i][j]/ np.sqrt(cov[i][i]*cov[j][j])
        
plt.imshow(pp_norm, cmap = 'seismic', vmin = -1, vmax = 1)
plt.colorbar()
plt.title("Final Covariance")
# Out:
# Dimension of cov: 600x600
# Text(0.5, 1.0, 'Final Covariance')

# %%
ffile[1].header
# Out:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -64 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 1000
# NAXIS2  =                 1000
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# COVDATA =                    T
# EXTNAME = 'COVMAT  '
# STRT_0  =                    0
# NAME_0  = 'xip     '
# STRT_1  =                  200
# NAME_1  = 'xim     '
# STRT_2  =                  400
# NAME_2  = 'gammat  '
# STRT_3  =                  880
# NAME_3  = 'wtheta  '

# %%
ffile[1].header.pop('STRT_2', None)
ffile[1].header.pop('NAME_2', None)
ffile[1].header.pop('STRT_3', None)
ffile[1].header.pop('NAME_3', None)
ffile[1].header['STRT_1'] = 300
ffile[1].header['NAXIS1'] = 600
ffile[1].header['NAXIS2'] = 600
ffile[1].data = cov

# %%
ffile[1].header
# Out:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -64 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                  600
# NAXIS2  =                  600
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# COVDATA =                    T
# EXTNAME = 'COVMAT  '
# STRT_0  =                    0
# NAME_0  = 'xip     '
# STRT_1  =                  300
# NAME_1  = 'xim     '

# %%
delve_data = run_dir.parent.parent / "LSSTY1_Data"

ztomo = np.load(delve_data / "ztomo_LSSTY1.npy")
nztomo = np.load(delve_data / "nztomo_LSSTY1.npy")

# %%
plt.plot(ztomo, nztomo[0], label = 'Source 1')
plt.plot(ztomo, nztomo[1], label = 'Source 2')
plt.plot(ztomo, nztomo[2], label = 'Source 3')
plt.plot(ztomo, nztomo[3], label = 'Source 4')
plt.plot(ztomo, nztomo[4], label = 'Source 5')
plt.show()

# %%
len(ztomo)
# Out:
# 400

# %%
plt.plot(ffile[4].data['Z_MID'], ffile[4].data['BIN1'], label = 'Source 1')
plt.plot(ffile[4].data['Z_MID'], ffile[4].data['BIN2'], label = 'Source 2')
plt.plot(ffile[4].data['Z_MID'], ffile[4].data['BIN3'], label = 'Source 3')
plt.plot(ffile[4].data['Z_MID'], ffile[4].data['BIN4'], label = 'Source 4')
plt.show()

# %%
ffile[4].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   56 / length of dimension 1
# NAXIS2  =                  300 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                    7 / number of table fields
# NZDATA  =                    T
# EXTNAME = 'nz_source'
# SIG_E_1 =   0.2435002682964671
# SIG_E_2 =   0.2621945854120855
# SIG_E_3 =   0.2588927276307921
# SIG_E_4 =   0.3096827008528927
# NGAL_1  =    1.475584985490327
# NGAL_2  =    1.479383426887689
# NGAL_3  =    1.483671693529899
# NGAL_4  =    1.461247850098986
# TTYPE1  = 'Z_LOW   '
# TFORM1  = 'D       '
# TTYPE2  = 'Z_MID   '
# TFORM2  = 'D       '
# TTYPE3  = 'Z_HIGH  '
# TFORM3  = 'D       '
# TTYPE4  = 'BIN1    '
# TFORM4  = 'D       '
# TTYPE5  = 'BIN2    '
# TFORM5  = 'D       '
# TTYPE6  = 'BIN3    '
# TFORM6  = 'D       '
# TTYPE7  = 'BIN4    '
# TFORM7  = 'D       '

# %%
# sigma_e = 0.26 (DESC SRD), neff = 10/arcmin^2 (DESC SRD)
n_density = [2.0, 
             2.0,
             2.0,
             2.0,
             2.0]

sigma_all = [0.26, 
             0.26,
             0.26,
             0.26,
             0.26]

zhead = ffile[4].header
zhead['NBIN'] = 5
zhead['NZ'] = 400

for i in range(5):
    zhead[f'NGAL_{i + 1}'] = n_density[i]
for i in range(5):
    zhead[f'SIG_E_{i + 1}'] = sigma_all[i]

zdata = ffile[4].data

dtype = np.dtype([
    ('Z_LOW', float), ('Z_MID', float), ('Z_HIGH', float),
    *[(f'BIN{i+1}', float) for i in range(5)]
])
znew = np.recarray(len(ztomo), dtype=dtype)
znew['Z_MID'] = ztomo
znew['Z_LOW'] = ztomo - ztomo[0]
znew['Z_HIGH'] = ztomo + ztomo[0]
for i in range(5):
    znew[f'BIN{i + 1}'] = nztomo[i]
ffile[4].data = znew

# %%
ffile[4].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   64 / length of dimension 1
# NAXIS2  =                  400 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                    8 / number of table fields
# NZDATA  =                    T
# EXTNAME = 'nz_source'
# SIG_E_1 =                 0.26
# SIG_E_2 =                 0.26
# SIG_E_3 =                 0.26
# SIG_E_4 =                 0.26
# NGAL_1  =                  2.0
# NGAL_2  =                  2.0
# NGAL_3  =                  2.0
# NGAL_4  =                  2.0
# NBIN    =                    5
# NZ      =                  400
# NGAL_5  =                  2.0
# SIG_E_5 =                 0.26
# TTYPE1  = 'Z_LOW   '
# TFORM1  = 'D       '
# TTYPE2  = 'Z_MID   '
# TFORM2  = 'D       '
# TTYPE3  = 'Z_HIGH  '
# TFORM3  = 'D       '
# TTYPE4  = 'BIN1    '
# TFORM4  = 'D       '
# TTYPE5  = 'BIN2    '
# TFORM5  = 'D       '
# TTYPE6  = 'BIN3    '
# TFORM6  = 'D       '
# TTYPE7  = 'BIN4    '
# TFORM7  = 'D       '
# TTYPE8  = 'BIN5    '
# TFORM8  = 'D       '

# %%
save_dirname = Path("LSSTY1_dcrimprint2pt_A_2pt")
os.makedirs(save_dirname, exist_ok=True)
os.makedirs(save_dirname / "figures", exist_ok=True)
savepath = save_dirname / "LSSTY1_dcrimprint2pt_A_2pt.fits"

# orig_dirname = Path("giulia_2pt")
# os.makedirs(orig_dirname, exist_ok=True)
# os.makedirs(orig_dirname / "figures", exist_ok=True)
# opath = orig_dirname / "giulia_2pt_example.fits"

ffile.writeto(savepath, overwrite=True)

# %% [markdown]
# import matplotlib as mpl
# mpl.rcParams.update(mpl.rcParamsDefault)
#
# T2 = twopoint.TwoPointFile.from_fits(opath)
# oldpath = opath.parent / "figures" / opath.stem
# T2.plots(oldpath, colormap='viridis', savepdf=False, latex=False, plot_spectrum=True, plot_kernel=True, plot_cov=True, cov_vmin=None, sharey=True, save_pickle=False, load_pickle=False, remove_pickle=True,label_legend ='', blind_yaxis=False, shade_until=None)

# %%
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

T3 = twopoint.TwoPointFile.from_fits(savepath)
spath = savepath.parent / "figures" / savepath.stem
T3.plots(spath, colormap='viridis', savepdf=False, latex=False, plot_spectrum=True, plot_kernel=True, plot_cov=True, cov_vmin=None, sharey=True, save_pickle=False, load_pickle=False, remove_pickle=True,label_legend ='', blind_yaxis=False, shade_until=None)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Saving LSSTY1_dcrimprint2pt_A_2pt/figures/LSSTY1_dcrimprint2pt_A_2pt_xip
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Saving LSSTY1_dcrimprint2pt_A_2pt/figures/LSSTY1_dcrimprint2pt_A_2pt_xim

# %%
savefile = fits.open(savepath)
#oldfile = fits.open(opath)

# %%
savefile.info()
# Out:
# Filename: DELVE_fiducial_A_2pt/DELVE_fiducial_A_2pt.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  COVMAT        1 ImageHDU        13   (400, 400)   float64
#   2  xip           1 BinTableHDU     39   200R x 8C   [K, K, K, D, D, D, D, D]
#   3  xim           1 BinTableHDU     39   200R x 8C   [K, K, K, D, D, D, D, D]
#   4  nz_source     1 BinTableHDU     34   60R x 7C   [D, D, D, D, D, D, D]

# %%
oldfile.info()
# Out:
# Filename: giulia_2pt/giulia_2pt_example.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  COVMAT        1 ImageHDU        17   (1000, 1000)   float64
#   2  xip           1 BinTableHDU     39   200R x 8C   [K, K, K, D, D, D, D, D]
#   3  xim           1 BinTableHDU     39   200R x 8C   [K, K, K, D, D, D, D, D]
#   4  gammat        1 BinTableHDU     37   480R x 7C   [K, K, K, D, D, D, D]
#   5  wtheta        1 BinTableHDU     39   120R x 8C   [K, K, K, D, D, D, D, D]
#   6  nz_source     1 BinTableHDU     32   300R x 7C   [D, D, D, D, D, D, D]
#   7  nz_lens       1 BinTableHDU     34   150R x 9C   [D, D, D, D, D, D, D, D, D]

# %%
zhead
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   56 / length of dimension 1
# NAXIS2  =                   60 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                    7 / number of table fields
# NZDATA  =                    T
# EXTNAME = 'nz_source'
# SIG_E_1 =                0.233
# SIG_E_2 =                0.259
# SIG_E_3 =                0.248
# SIG_E_4 =                0.289
# NGAL_1  =                1.293
# NGAL_2  =                 1.15
# NGAL_3  =                1.169
# NGAL_4  =                1.153
# NBIN    =                    4
# NZ      =                  300
# TTYPE1  = 'Z_LOW   '
# TFORM1  = 'D       '
# TTYPE2  = 'Z_MID   '
# TFORM2  = 'D       '
# TTYPE3  = 'Z_HIGH  '
# TFORM3  = 'D       '
# TTYPE4  = 'BIN1    '
# TFORM4  = 'D       '
# TTYPE5  = 'BIN2    '
# TFORM5  = 'D       '
# TTYPE6  = 'BIN3    '
# TFORM6  = 'D       '
# TTYPE7  = 'BIN4    '
# TFORM7  = 'D       '
