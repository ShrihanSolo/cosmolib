# %%
import getdist
from getdist import plots, MCSamples
from getdist.paramnames import escapeLatex, makeList, mergeRenames
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from pathlib import Path
# %matplotlib inline


g = plots.getSubplotPlotter(width_inch=8)

# %%
newfidA = Path.home() / 'weaklens' / 'cosmolib' / 'output' / 'shrihan-clean-des-y3-fidA-nautilus.txt'
newfidB = Path.home() / 'weaklens' / 'cosmolib' / 'output' / 'shrihan-clean-des-y3-fidB-nautilus.txt'
newfidC = Path.home() / 'weaklens' / 'cosmolib' / 'output' / 'shrihan-clean-des-y3-fidC-nautilus.txt'
delvefidA = Path.home() / 'weaklens' / 'cosmolib' / 'output' / 'shrihan-clean-delve-dr3-fidA-nautilus.txt'
delvefidB = Path.home() / 'weaklens' / 'cosmolib' / 'output' / 'shrihan-clean-delve-dr3-fidB-nautilus.txt'
delvefidC = Path.home() / 'weaklens' / 'cosmolib' / 'output' / 'shrihan-clean-delve-dr3-fidC-nautilus.txt'

#imprintresp = Path.home() / 'weaklens' / 'cosmolib' / 'output' / 'shrihan-des-y3-response2_A.txt'
newfidA_chains = np.genfromtxt(newfidA, names=True)
newfidB_chains = np.genfromtxt(newfidB, names=True)
newfidC_chains = np.genfromtxt(newfidC, names=True)
delvefidA_chains = np.genfromtxt(delvefidA, names=True)
delvefidB_chains = np.genfromtxt(delvefidB, names=True)
delvefidC_chains = np.genfromtxt(delvefidC, names=True)

# %%
omm = 0.#,#0.03
oss = 0.#,#0.03

uu = newfidA_chains
newfidA_samples = MCSamples(samples=np.c_[uu['cosmological_parametersomega_m']+omm,uu['COSMOLOGICAL_PARAMETERSSIGMA_8'],
                                (uu['COSMOLOGICAL_PARAMETERSSIGMA_8'])*np.sqrt((uu['cosmological_parametersomega_m'])/0.3)+oss,
                                 uu['cosmological_parametersn_s'], uu['cosmological_parametersomega_b'], uu['cosmological_parametersh0']],
                                 weights=np.exp(uu['log_weight']), names = ['Om','sigma8','s8','ns', 'Ob', 'h0'], labels = ['\Omega_{m}','\sigma_8','S_8','n_s','\Omega_b', 'h'])


uu = newfidB_chains
newfidB_samples = MCSamples(samples=np.c_[uu['cosmological_parametersomega_m']+omm,uu['COSMOLOGICAL_PARAMETERSSIGMA_8'],
                                (uu['COSMOLOGICAL_PARAMETERSSIGMA_8'])*np.sqrt((uu['cosmological_parametersomega_m'])/0.3)+oss,
                                 uu['cosmological_parametersn_s'], uu['cosmological_parametersomega_b'], uu['cosmological_parametersh0']],
                                 weights=np.exp(uu['log_weight']), names = ['Om','sigma8','s8','ns', 'Ob', 'h0'], labels = ['\Omega_{m}','\sigma_8','S_8','n_s','\Omega_b', 'h'])

uu = newfidC_chains
newfidC_samples = MCSamples(samples=np.c_[uu['cosmological_parametersomega_m']+omm,uu['COSMOLOGICAL_PARAMETERSSIGMA_8'],
                                (uu['COSMOLOGICAL_PARAMETERSSIGMA_8'])*np.sqrt((uu['cosmological_parametersomega_m'])/0.3)+oss,
                                 uu['cosmological_parametersn_s'], uu['cosmological_parametersomega_b'], uu['cosmological_parametersh0']],
                                 weights=np.exp(uu['log_weight']), names = ['Om','sigma8','s8','ns', 'Ob', 'h0'], labels = ['\Omega_{m}','\sigma_8','S_8','n_s','\Omega_b', 'h'])


uu = delvefidA_chains
delvefidA_samples = MCSamples(samples=np.c_[uu['cosmological_parametersomega_m']+omm,uu['COSMOLOGICAL_PARAMETERSSIGMA_8'],
                                (uu['COSMOLOGICAL_PARAMETERSSIGMA_8'])*np.sqrt((uu['cosmological_parametersomega_m'])/0.3)+oss,
                                 uu['cosmological_parametersn_s'], uu['cosmological_parametersomega_b'], uu['cosmological_parametersh0']],
                                 weights=np.exp(uu['log_weight']), names = ['Om','sigma8','s8','ns', 'Ob', 'h0'], labels = ['\Omega_{m}','\sigma_8','S_8','n_s','\Omega_b', 'h'])

uu = delvefidB_chains
delvefidB_samples = MCSamples(samples=np.c_[uu['cosmological_parametersomega_m']+omm,uu['COSMOLOGICAL_PARAMETERSSIGMA_8'],
                                (uu['COSMOLOGICAL_PARAMETERSSIGMA_8'])*np.sqrt((uu['cosmological_parametersomega_m'])/0.3)+oss,
                                 uu['cosmological_parametersn_s'], uu['cosmological_parametersomega_b'], uu['cosmological_parametersh0']],
                                 weights=np.exp(uu['log_weight']), names = ['Om','sigma8','s8','ns', 'Ob', 'h0'], labels = ['\Omega_{m}','\sigma_8','S_8','n_s','\Omega_b', 'h'])

uu = delvefidC_chains
delvefidC_samples = MCSamples(samples=np.c_[uu['cosmological_parametersomega_m']+omm,uu['COSMOLOGICAL_PARAMETERSSIGMA_8'],
                                (uu['COSMOLOGICAL_PARAMETERSSIGMA_8'])*np.sqrt((uu['cosmological_parametersomega_m'])/0.3)+oss,
                                 uu['cosmological_parametersn_s'], uu['cosmological_parametersomega_b'], uu['cosmological_parametersh0']],
                                 weights=np.exp(uu['log_weight']), names = ['Om','sigma8','s8','ns', 'Ob', 'h0'], labels = ['\Omega_{m}','\sigma_8','S_8','n_s','\Omega_b', 'h'])

g.settings.axes_labelsize = 20
g.settings.axes_fontsize =15
g.settings.legend_fontsize = 20
g.settings.linewidth = 2
# Out:
# WARNING:root:outlier fraction 4.6816479400749066e-05
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
g.triangle_plot([newfidA_samples, newfidB_samples, newfidC_samples, delvefidA_samples, delvefidB_samples, delvefidC_samples], ['Om', 'sigma8', 's8'], filled=[False,False,False, True, True, True], 
                colors=['coral','coral', 'coral', 'black','black', 'black'], alphas=[1.0, 1.0, 1.0, 0.5, 0.5, 0.5],
                legend_labels=['DES Fiducial A', 'DES Fiducial B', 'DES Fiducial C', 'DELVE Fiducial A', 'DELVE Fiducial B', 'DELVE Fiducial C'],  legend_loc='upper right',fontsize=40, 
                contour_colors=['coral','coral', 'coral', 'black','black', 'black'],
                ls = ['-','-','-','-'], contour_ls = ['-','-','-','-'])
#plt.savefig('desVdelve_all.png', dpi=600, bbox_inches='tight', transparent=True)
