# %%
import getdist
from getdist import plots, MCSamples
from getdist.paramnames import escapeLatex, makeList, mergeRenames
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from pathlib import Path
# %matplotlib inline


g = plots.getSubplotPlotter(width_inch=8)

# %%
newfidA = Path.home() / 'weaklens' / 'cosmolib' / 'output' / 'shrihan-clean-delve-dr3-fidA-nautilus.txt'
newfidB = Path.home() / 'weaklens' / 'cosmolib' / 'output' / 'shrihan-clean-delve-dr3-psfA-nautilus.txt'
newfidC = Path.home() / 'weaklens' / 'cosmolib' / 'output' / 'shrihan-clean-delve-dr3-respA-nautilus.txt'
newfidD = Path.home() / 'weaklens' / 'cosmolib' / 'output' / 'shrihan-clean-delve-dr3-dcrA-nautilus.txt'

#imprintresp = Path.home() / 'weaklens' / 'cosmolib' / 'output' / 'shrihan-des-y3-response2_A.txt'
newfidA_chains = np.genfromtxt(newfidA, names=True)
newfidB_chains = np.genfromtxt(newfidB, names=True)
newfidC_chains = np.genfromtxt(newfidC, names=True)
newfidD_chains = np.genfromtxt(newfidD, names=True)
# Out:
# /home/shrihan/ipykernel_416357/735429940.py:10: UserWarning: genfromtxt: Empty input file: "/home/shrihan/weaklens/cosmolib/output/shrihan-clean-delve-dr3-dcrA-nautilus.txt"
#   newfidD_chains = np.genfromtxt(newfidD, names=True)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 10
#       8 newfidB_chains = np.genfromtxt(newfidB, names=True)
#       9 newfidC_chains = np.genfromtxt(newfidC, names=True)
# ---> 10 newfidD_chains = np.genfromtxt(newfidD, names=True)
#
# File /scratch/midway3/shrihan/ana/.conda/envs/weaklens2/lib/python3.10/site-packages/numpy/lib/npyio.py:2023, in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, ndmin, like)
#    2021 # Should we take the first values as names ?
#    2022 if names is True:
# -> 2023     fval = first_values[0].strip()
#    2024     if comments is not None:
#    2025         if fval in comments:
#
# IndexError: list index out of range

# %%
omm = 0.#,#0.03
oss = 0.#,#0.03

uu = newfidA_chains
newfidA_samples = MCSamples(samples=np.c_[uu['cosmological_parametersomega_m']+omm,uu['COSMOLOGICAL_PARAMETERSSIGMA_8'],
                                (uu['COSMOLOGICAL_PARAMETERSSIGMA_8'])*np.sqrt((uu['cosmological_parametersomega_m'])/0.3)+oss,
                                 uu['cosmological_parametersn_s'], uu['cosmological_parametersomega_b'], uu['cosmological_parametersh0']],
                                 weights=np.exp(uu['log_weight']), names = ['Om','sigma8','s8','ns', 'Ob', 'h0'], labels = ['\Omega_{m}','\sigma_8','S_8','n_s','\Omega_b', 'h'])


uu = newfidB_chains
newfidB_samples = MCSamples(samples=np.c_[uu['cosmological_parametersomega_m']+omm,uu['COSMOLOGICAL_PARAMETERSSIGMA_8'],
                                (uu['COSMOLOGICAL_PARAMETERSSIGMA_8'])*np.sqrt((uu['cosmological_parametersomega_m'])/0.3)+oss,
                                 uu['cosmological_parametersn_s'], uu['cosmological_parametersomega_b'], uu['cosmological_parametersh0']],
                                 weights=np.exp(uu['log_weight']), names = ['Om','sigma8','s8','ns', 'Ob', 'h0'], labels = ['\Omega_{m}','\sigma_8','S_8','n_s','\Omega_b', 'h'])

uu = newfidC_chains
newfidC_samples = MCSamples(samples=np.c_[uu['cosmological_parametersomega_m']+omm,uu['COSMOLOGICAL_PARAMETERSSIGMA_8'],
                                (uu['COSMOLOGICAL_PARAMETERSSIGMA_8'])*np.sqrt((uu['cosmological_parametersomega_m'])/0.3)+oss,
                                 uu['cosmological_parametersn_s'], uu['cosmological_parametersomega_b'], uu['cosmological_parametersh0']],
                                 weights=np.exp(uu['log_weight']), names = ['Om','sigma8','s8','ns', 'Ob', 'h0'], labels = ['\Omega_{m}','\sigma_8','S_8','n_s','\Omega_b', 'h'])


uu = newfidD_chains
newfidD_samples = MCSamples(samples=np.c_[uu['cosmological_parametersomega_m']+omm,uu['COSMOLOGICAL_PARAMETERSSIGMA_8'],
                                (uu['COSMOLOGICAL_PARAMETERSSIGMA_8'])*np.sqrt((uu['cosmological_parametersomega_m'])/0.3)+oss,
                                 uu['cosmological_parametersn_s'], uu['cosmological_parametersomega_b'], uu['cosmological_parametersh0']],
                                 weights=np.exp(uu['log_weight']), names = ['Om','sigma8','s8','ns', 'Ob', 'h0'], labels = ['\Omega_{m}','\sigma_8','S_8','n_s','\Omega_b', 'h'])



g.settings.axes_labelsize = 20
g.settings.axes_fontsize =15
g.settings.legend_fontsize = 20
g.settings.linewidth = 2
# Out:
# Removed no burn in
# WARNING:root:outlier fraction 4.572891896835559e-05
# WARNING:root:outlier fraction 4.746535029428517e-05
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
g.triangle_plot(
    [newfidA_samples, newfidB_samples, newfidC_samples, newfidD_samples],
    ['sigma8', 's8', 'Om', 'ns', 'Ob', 'h0'],
    filled=[True, False, False, False, True, True],
    colors=['coral', 'blue', 'green', 'black', 'black', 'black'],
    alphas=[0.7, 1.0, 1.0, 1.0, 0.5, 0.5],
    legend_labels=None,  # Turn off legend
    legend_loc=None,
    fontsize=40,
    contour_colors=['coral', 'blue', 'green', 'black'],
    ls=['-', '-', '-', '-'],
    contour_ls=['-', '-', '-', '-']
)
plt.savefig('DECADE_All_Imprints.png', dpi=600, bbox_inches='tight', transparent=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 g.triangle_plot(
# ----> 2     [newfidA_samples, newfidB_samples, newfidC_samples, newfidD_samples],
#       3     ['sigma8', 's8', 'Om', 'ns', 'Ob', 'h0'],
#       4     filled=[True, False, False, False, True, True],
#       5     colors=['coral', 'blue', 'green', 'black', 'black', 'black'],
#       6     alphas=[0.7, 1.0, 1.0, 1.0, 0.5, 0.5],
#       7     legend_labels=None,  # Turn off legend
#       8     legend_loc=None,
#       9     fontsize=40,
#      10     contour_colors=['coral', 'blue', 'green', 'black'],
#      11     ls=['-', '-', '-', '-'],
#      12     contour_ls=['-', '-', '-', '-']
#      13 )
#      14 plt.savefig('DECADE_All_Imprints.png', dpi=600, bbox_inches='tight', transparent=True)
#
# NameError: name 'newfidA_samples' is not defined
