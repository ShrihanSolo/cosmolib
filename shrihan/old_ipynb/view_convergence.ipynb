# %%
import pandas as pd

# %%
live = pd.read_csv('../output/y3-polychord-checkpoints/y3_phys_live.txt', delim_whitespace=True, header=None)

# %%
live
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.283589  0.813339  0.054794  0.962834  0.715703  0.160135 -0.011825
# 1    0.636061  0.792605  0.047093  1.047799  0.710676  0.122970 -0.007320
# 2    0.603297  0.645616  0.062728  0.930069  0.805750  0.487210 -0.012512
# 3    0.426593  0.563712  0.037503  1.044380  0.740552  0.203069 -0.010168
# 4    0.674625  0.554834  0.069872  0.946227  0.748873  0.421223 -0.001384
# ..        ...       ...       ...       ...       ...       ...       ...
# 245  0.397103  0.692415  0.067449  1.046385  0.776487  0.323861 -0.010428
# 246  0.362768  0.704690  0.051524  0.905712  0.825218  0.377960 -0.019055
# 247  0.673972  0.682620  0.057134  1.049238  0.839207  0.488459 -0.003751
# 248  0.745208  0.728224  0.051079  0.911361  0.776509  0.133850 -0.017915
# 249  0.553393  0.733287  0.032083  0.976381  0.829274  0.472341 -0.009402
#
#            7         8         9   ...        14        15        16  \
# ...

# %%
import matplotlib.pyplot as plt
for i in range(0, 6):
    plt.plot(live[i])
